# %%
import pandas as pd
import numpy as np
import seaborn as sb
import os
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
#Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT=DecisionTreeClassifier()

# %%
del df

# %%
df=pd.read_csv('mainData.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
X=df.drop('class',axis=1).values

# %%
Y=df['class'].values

# %%
df.dropna(inplace=True)

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.3)

# %%
len(df['class'].unique())
# Out:
# 331

# %%
for i in range(63743):
    df.iloc[i]['class']=dictionary[df.iloc[i]['class']]

# %%
df.iloc[0]['class']=dictionary[df.iloc[0]['class']]

# %%
dictionary[df.iloc[100]['class']]

# %%
df.describe()

# %%
df.info()

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y)

# %%
DT.fit(Xtrain,Ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
DT=pickle.load(open('DecisionTreeclf.pkl','rb'))

# %%
predTree=DT.predict(Xtest)

# %%
# Decision Tree

# %%
print(classification_report(Ytest,predTree))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.63      0.56      0.59        57
#            2       0.61      0.52      0.56        64
#            3       0.63      0.50      0.56        66
#            4       0.48      0.54      0.51        54
#            5       0.44      0.45      0.44        58
#            6       0.64      0.65      0.64        65
#            7       0.59      0.47      0.53        55
#            8       0.56      0.64      0.60        58
#            9       0.54      0.51      0.52        55
#           10       0.47      0.48      0.47        56
#           11       0.61      0.50      0.55        60
#           12       0.44      0.49      0.47        61
#           13       0.50      0.51      0.50        59
#           14       0.48      0.51      0.50        55
#           15       0.53      0.53      0.53        55
#           16       0.54      0.59      0.56        58
# ...

# %%
pickle.dump(DT, open("DecisionTreeclf.pkl", 'wb'))

# %%
# Random forrest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y)

# %%
rfc=RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(Xtrain,Ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predrfc=rfc.predict(Xtest)
print(classification_report(Ytest,predrfc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.77      0.72        57
#            2       0.63      0.48      0.55        64
#            3       0.69      0.55      0.61        66
#            4       0.51      0.44      0.48        54
#            5       0.47      0.50      0.48        58
#            6       0.48      0.66      0.55        65
#            7       0.68      0.47      0.56        55
#            8       0.54      0.60      0.57        58
#            9       0.49      0.45      0.47        55
#           10       0.51      0.45      0.48        56
#           11       0.55      0.45      0.50        60
#           12       0.46      0.44      0.45        61
#           13       0.40      0.58      0.48        59
#           14       0.53      0.53      0.53        55
#           15       0.43      0.47      0.45        55
#           16       0.56      0.55      0.56        58
# ...
